# %% [markdown]
# #STEP PRESENTATION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plot = sns.barplot(y='MonthlyCharges', x= 'TechSupport', hue ="PhoneService", data =df)
plt.show()

# %%
df["DeviceProtection"].describe()
# Out:
# count     7043
# unique       3
# top         No
# freq      3095
# Name: DeviceProtection, dtype: object

# %%
import time  as t

t

currenttime= t.localtime(t.time())
print ("Current time is", currenttime)
# Out:
# Current time is time.struct_time(tm_year=2024, tm_mon=1, tm_mday=28, tm_hour=18, tm_min=49, tm_sec=44, tm_wday=6, tm_yday=28, tm_isdst=0)
